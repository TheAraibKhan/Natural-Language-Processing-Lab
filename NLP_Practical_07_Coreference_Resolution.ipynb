# %% [markdown]
# <a href="https://colab.research.google.com/github/TheAraibKhan/Natural-Language-Processing-Lab/blob/main/NLP_Practical_07_Coreference_Resolution.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Natural Language Processing Laboratory
#
# Practical 7: Coreference Resolution using a Similar Approach
#
# Name: Araib Khan
# Course: B.Tech CSE (Artificial Intelligence)
# Subject: Natural Language Processing Laboratory
# Practical No.: 7
# CO: CO2
#
# Objective:
# To identify pronouns and resolve them to the entities they refer to
# using a simple rule-based coreference resolution approach.

# %%
import re

print("Libraries imported successfully.")
# Out:
# Libraries imported successfully.

# %%
text = """
Alice went to the library because she needed a book.
The librarian helped Alice find the book, and she thanked her.
Alice took the book home because she wanted to study it.
"""

print("Original Text:")
print(text)
# Out:
# Original Text:
#
# Alice went to the library because she needed a book.
# The librarian helped Alice find the book, and she thanked her.
# Alice took the book home because she wanted to study it.

# %%
sentences = [s.strip() for s in text.strip().split(".") if s.strip()]

print("Sentences:\n")

for i, sentence in enumerate(sentences, 1):
    print(f"{i}. {sentence}.")
# Out:
# Sentences:
#
# 1. Alice went to the library because she needed a book.
# 2. The librarian helped Alice find the book, and she thanked her.
# 3. Alice took the book home because she wanted to study it.

# %%
coreference_rules = {
    "she": "Alice",
    "her": "Alice",
    "he": "Alice",
    "him": "Alice",
    "his": "Alice",
    "it": "the book"
}

print("Coreference Rules:")
for pronoun, entity in coreference_rules.items():
    print(f"{pronoun} -> {entity}")
# Out:
# Coreference Rules:
# she -> Alice
# her -> Alice
# he -> Alice
# him -> Alice
# his -> Alice
# it -> the book

# %%
resolved_text = text

for pronoun, entity in coreference_rules.items():
    pattern = r"\b" + pronoun + r"\b"
    resolved_text = re.sub(
        pattern,
        entity,
        resolved_text,
        flags=re.IGNORECASE
    )

print("Resolved Text:")
print(resolved_text)
# Out:
# Resolved Text:
#
# Alice went to the library because Alice needed a book.
# The librarian helped Alice find the book, and Alice thanked Alice.
# Alice took the book home because Alice wanted to study the book.

# %%
print("Detected Coreferences:\n")

for pronoun, entity in coreference_rules.items():
    if re.search(r"\b" + pronoun + r"\b", text, flags=re.IGNORECASE):
        print(f"{pronoun} -> {entity}")
# Out:
# Detected Coreferences:
#
# she -> Alice
# her -> Alice
# it -> the book

# %%
print("Original Text:")
print(text)

print("=" * 70)

print("Resolved Text:")
print(resolved_text)
# Out:
# Original Text:
#
# Alice went to the library because she needed a book.
# The librarian helped Alice find the book, and she thanked her.
# Alice took the book home because she wanted to study it.
#
# ...
# Resolved Text:
#
# Alice went to the library because Alice needed a book.
# The librarian helped Alice find the book, and Alice thanked Alice.
# Alice took the book home because Alice wanted to study the book.

# %%
# Result:
# Coreference resolution was successfully demonstrated using a simple
# rule-based approach. Pronouns in the text were identified and mapped
# to their corresponding entities.
#
# Conclusion:
# Coreference resolution helps identify different expressions that refer
# to the same entity. It improves document-level understanding and is
# useful in tasks such as information extraction, summarization,
# question answering, and document analysis.
